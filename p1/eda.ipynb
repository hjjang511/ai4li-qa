# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("gesture_dataset.csv")

# %%
df.head()  # Hiển thị 5 dòng đầu tiên
# Out:
#    frame_index  x0  y0  x2  y1  x4  y2  x6  y3  x8  ...  y16  x34  y17  x36  \
# 0            0   0   0  21 -20  41 -38  57 -56  74  ... -123  -33  -56  -43
# 1            1   0   0  20 -20  41 -39  57 -56  74  ... -124  -33  -56  -43
# 2            2   0   0  21 -21  41 -40  58 -56  74  ... -125  -33  -57  -43
# 3            3   0   0  21 -19  41 -39  57 -55  74  ... -124  -33  -56  -43
# 4            4   0   0  20 -20  41 -39  57 -55  74  ... -124  -33  -56  -44
#
#    y18  x38  y19  x40  y20  label
# 0  -77  -50  -88  -56  -99      a
# 1  -77  -49  -89  -55 -100      a
# 2  -78  -49  -90  -55 -101      a
# 3  -76  -50  -89  -56 -100      a
# 4  -76  -50  -89  -56 -100      a
#
# [5 rows x 44 columns]

# %%
print("📊 Kích thước dataset:", df.shape)
print("🧾 Cột:", df.columns.tolist())
# Out:
# 📊 Kích thước dataset: (631, 44)
# 🧾 Cột: ['frame_index', 'x0', 'y0', 'x2', 'y1', 'x4', 'y2', 'x6', 'y3', 'x8', 'y4', 'x10', 'y5', 'x12', 'y6', 'x14', 'y7', 'x16', 'y8', 'x18', 'y9', 'x20', 'y10', 'x22', 'y11', 'x24', 'y12', 'x26', 'y13', 'x28', 'y14', 'x30', 'y15', 'x32', 'y16', 'x34', 'y17', 'x36', 'y18', 'x38', 'y19', 'x40', 'y20', 'label']

# %%
df["label"].value_counts()
# Out:
# label
# q    103
# r     91
# t     80
# a     78
# e     71
# c     61
# d     58
# b     53
# đ     36
# Name: count, dtype: int64

# %%
df.isnull().sum()
# Out:
# frame_index    0
# x0             0
# y0             0
# x2             0
# y1             0
# x4             0
# y2             0
# x6             0
# y3             0
# x8             0
# y4             0
# x10            0
# y5             0
# x12            0
# y6             0
# x14            0
# y7             0
# x16            0
# y8             0
# x18            0
# y9             0
# x20            0
# y10            0
# x22            0
# y11            0
# x24            0
# y12            0
# x26            0
# y13            0
# x28            0
# y14            0
# x30            0
# y15            0
# x32            0
# y16            0
# x34            0
# y17            0
# x36            0
# y18            0
# x38            0
# y19            0
# x40            0
# y20            0
# label          0
# dtype: int64

# %%
import matplotlib.pyplot as plt

df.drop(columns=["frame_index", "label"]).boxplot(figsize=(18, 6))
plt.title("📦 Boxplot các tọa độ x/y (sau chuẩn hóa theo cổ tay)")
plt.show()
# Out:
# d:\AI4LI\pytorch-openpose\openpose-env\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 128230 (\N{PACKAGE}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.histplot(data=df, x="frame_index", hue="label", multiple="stack")
plt.title("⏱️ Phân bố frame theo nhãn")
plt.show()
# Out:
# d:\AI4LI\pytorch-openpose\openpose-env\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 9201 (\N{STOPWATCH}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
df.to_csv("gesture_dataset_cleaned.csv", index=False)
